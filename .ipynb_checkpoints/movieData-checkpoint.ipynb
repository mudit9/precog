# %%
from bs4 import BeautifulSoup
import urllib2
import csv
from pymongo import MongoClient
from pprint import pprint
import urllib
import pandas as pd
import json

df = pd.read_csv('imdb.csv')
df.drop_duplicates(subset='Name')
# Out:
#                                                   Name    Year of release  \
# 0                                                Polar             (2019)
# 1                                         The Punisher           (2017– )
# 2                                      Game of Thrones           (2011– )
# 3                                              Aquaman             (2018)
# 4                                              Vikings           (2013– )
# 5                Fast & Furious Presents: Hobbs & Shaw             (2019)
# 6    Birds of Prey (And the Fantabulous Emancipatio...             (2020)
# 7                                               Titans       (I) (2018– )
# 8                                  Alita: Battle Angel             (2019)
# 9                                              Kingdom           (2019– )
# 10                                      Mortal Engines             (2018)
# 11                                   Avengers: Endgame             (2019)
# 12                   Spider-Man: Into the Spider-Verse             (2018)
# 13          How to Train Your Dragon: The Hidden World             (2019)
# 14                                Star Trek: Discovery           (2017– )
# 15                            Doragon bôru chô: Burorî             (2018)
# 16                                              Gotham           (2014– )
# 17                                               Close         (I) (2019)
# 18                                  Kingdom Hearts III  (2019 Video Game)
# 19                                         The Passage           (2019– )
# 20                                           The Flash           (2014– )
# 21                                       Black Panther             (2018)
# 22                                           Bumblebee             (2018)
# 23                                      Captain Marvel             (2019)
# 24                              Avengers: Infinity War             (2018)
# 25                             Solo: A Star Wars Story             (2018)
# 26                                               Arrow           (2012– )
# 27                                       Hunter Killer             (2018)
# 28                        The Girl in the Spider's Web             (2018)
# 29                           Spider-Man: Far From Home             (2019)
# ..                                                 ...                ...
# 237                         Avatar: The Last Airbender        (2003–2008)
# 238                                    Steven Universe           (2013– )
# 239                                  The Addams Family             (2019)
# 240                                            Tangled             (2010)
# 241                                          Toy Story             (1995)
# 242                                        Toy Story 3             (2010)
# 243                                           Hercules             (1997)
# 244                                      American Dad!           (2005– )
# 245                                   King of the Hill        (1997–2010)
# 246                      Sen to Chihiro no kamikakushi             (2001)
# 247                                     Wreck-It Ralph             (2012)
# 248                                     Kimi no na wa.             (2016)
# 249                                 Shingeki no kyojin           (2013– )
# 250        Extremely Wicked, Shockingly Evil, and Vile             (2019)
# 256                                     Velvet Buzzsaw             (2019)
# 265                                           Suspiria         (I) (2018)
# 267                                              Split        (IX) (2016)
# 273                                      The Blacklist           (2013– )
# 279                                             Luther           (2010– )
# 280                                       Breaking Bad        (2008–2013)
# 281                  Law & Order: Special Victims Unit           (1999– )
# 282                         Bad Times at the El Royale             (2018)
# 284                                    It: Chapter Two             (2019)
# 287                                 Black Earth Rising           (2018– )
# 289                                         The Sinner           (2017– )
# 290                                           Tin Star           (2017– )
# 291                                              Ozark           (2017– )
# 295                         The Haunting of Hill House           (2018– )
# 296                              American Horror Story           (2011– )
# 298                                             Climax         (I) (2018)
#
#      Rating                                       Genre  \
# 0       6.3                 \nAction, Crime
# 1       8.6      \nAction, Adventure, Crime
# 2       9.5      \nAction, Adventure, Drama
# 3       7.4    \nAction, Adventure, Fantasy
# 4       8.6      \nAction, Adventure, Drama
# 5       NaN             \nAction, Adventure
# 6       NaN      \nAction, Adventure, Crime
# 7       8.2      \nAction, Adventure, Drama
# 8       7.8    \nAction, Adventure, Romance
# 9       8.5              \nAction, Thriller
# 10      6.3    \nAction, Adventure, Fantasy
# 11      NaN    \nAction, Adventure, Fantasy
# 12      8.7  \nAnimation, Action, Adventure
# 13      8.1  \nAnimation, Action, Adventure
# 14      7.4      \nAction, Adventure, Drama
# 15      8.3    \nAnimation, Action, Fantasy
# 16      7.9          \nAction, Crime, Drama
# 17      5.6              \nAction, Thriller
# 18      9.7    \nAction, Adventure, Fantasy
# 19      7.4      \nAction, Adventure, Drama
# 20      7.9      \nAction, Adventure, Drama
# 21      7.4     \nAction, Adventure, Sci-Fi
# 22      7.1     \nAction, Adventure, Sci-Fi
# 23      NaN     \nAction, Adventure, Sci-Fi
# 24      8.5    \nAction, Adventure, Fantasy
# 25      7.0    \nAction, Adventure, Fantasy
# 26      7.7      \nAction, Adventure, Crime
# 27      6.6              \nAction, Thriller
# 28      6.1          \nAction, Crime, Drama
# 29      NaN     \nAction, Adventure, Comedy
# ..      ...                                         ...
# 237     9.2  \nAnimation, Action, Adventure
# 238     8.3  \nAnimation, Action, Adventure
# 239     NaN     \nAnimation, Comedy, Family
# 240     7.8  \nAnimation, Adventure, Comedy
# 241     8.3  \nAnimation, Adventure, Comedy
# 242     8.3  \nAnimation, Adventure, Comedy
# 243     7.3  \nAnimation, Adventure, Comedy
# 244     7.4             \nAnimation, Comedy
# 245     7.3      \nAnimation, Comedy, Drama
# 246     8.6  \nAnimation, Adventure, Family
# 247     7.7  \nAnimation, Adventure, Comedy
# 248     8.4     \nAnimation, Drama, Fantasy
# 249     8.8  \nAnimation, Action, Adventure
# 250     8.0    \nBiography, Crime, Thriller
# 256     5.9     \nHorror, Mystery, Thriller
# 265     7.0      \nFantasy, Horror, Mystery
# 267     7.3              \nHorror, Thriller
# 273     8.1         \nCrime, Drama, Mystery
# 279     8.5         \nCrime, Drama, Mystery
# 280     9.5        \nCrime, Drama, Thriller
# 281     8.0         \nCrime, Drama, Mystery
# 282     7.2         \nCrime, Drama, Mystery
# 284     NaN              \nHorror, Thriller
# 287     6.9                      \nThriller
# 289     8.0         \nCrime, Drama, Mystery
# 290     7.3        \nCrime, Drama, Thriller
# 291     8.3        \nCrime, Drama, Thriller
# 295     8.8        \nDrama, Horror, Mystery
# 296     8.1       \nDrama, Horror, Thriller
# 298     7.5          \nDrama, Horror, Music
#
#                                               imdb Url      votes
# 0    http://www.imdb.com/title/tt4139588/?ref_=adv_...     28,030
# 1    http://www.imdb.com/title/tt5675620/?ref_=adv_...    132,557
# 2    http://www.imdb.com/title/tt0944947/?ref_=adv_...  1,406,544
# 3    http://www.imdb.com/title/tt1477834/?ref_=adv_...    157,477
# 4    http://www.imdb.com/title/tt2306299/?ref_=adv_...    323,777
# 267  http://www.imdb.com/title/tt4972582/?ref_=adv_...    328,165
# 273  http://www.imdb.com/title/tt2741602/?ref_=adv_...    151,307
# 279  http://www.imdb.com/title/tt1474684/?ref_=adv_...    100,909
# 280  http://www.imdb.com/title/tt0903747/?ref_=adv_...  1,156,207
# 281  http://www.imdb.com/title/tt0203259/?ref_=adv_...     66,511
# 282  http://www.imdb.com/title/tt6628394/?ref_=adv_...     62,673
# 284  http://www.imdb.com/title/tt7349950/?ref_=adv_...        NaN
# 287  http://www.imdb.com/title/tt7660730/?ref_=adv_...      1,568
# 289  http://www.imdb.com/title/tt6048596/?ref_=adv_...     51,723
# 290  http://www.imdb.com/title/tt4607112/?ref_=adv_...      7,522
# 291  http://www.imdb.com/title/tt5071412/?ref_=adv_...     98,566
# 295  http://www.imdb.com/title/tt6763664/?ref_=adv_...     99,827
# 296  http://www.imdb.com/title/tt1844624/?ref_=adv_...    245,066
# 298  http://www.imdb.com/title/tt8359848/?ref_=adv_...      9,812
#
# [193 rows x 6 columns]

# %%
movieid = []
for i in range(1,301):
    movieid.append(i)
df['MovieID'] = movieid
df['Adventure']=0
df['Drama']=0
df['Comedy']=0
df['Animation']=0
df['Sci-fi']=0
df['Thriller']=0
df['Action']=0
df['Mystery']=0
for i,r in df.iterrows():
    if (r['Genre'].find('Action')!=-1):
        df.set_value(i,'Action',1)
    else:
        df.set_value(i,'Action',0)
        
    if (r['Genre'].find('Adventure')!=-1):
        df.set_value(i,'Adventure',1)
    else:
        df.set_value(i,'Adventure',0)
        
    if (r['Genre'].find('Drama')!=-1):
        df.set_value(i,'Drama',1)
    else:
        df.set_value(i,'Drama',0)
        
    if (r['Genre'].find('Comedy')!=-1):
        df.set_value(i,'Comedy',1)
    else:
        df.set_value(i,'Comedy',0)
        
    if (r['Genre'].find('Animation')!=-1):
        df.set_value(i,'Animation',1)
    else:
        df.set_value(i,'Animation',0)
        
    if (r['Genre'].find('Sci-fi')!=-1):
        df.set_value(i,'Sci-fi',1)
    else:
        df.set_value(i,'Sci-fi',0)
    
    if (r['Genre'].find('Thriller')!=-1):
        df.set_value(i,'Thriller',1)
    else:
        df.set_value(i,'Thriller',0)
        
    if (r['Genre'].find('Mystery')!=-1):
        df.set_value(i,'Mystery',1)
    else:
        df.set_value(i,'Mystery',0)

# %%
df['Name'].nunique()
# Out:
# 193

# %%
client = MongoClient(port=27017)
db=client.movie
collection = db.movie
collection.drop
collection.insert_many(df.to_dict('records'))
collection.count_documents({})
#pprint(collection.find_one({"Name": "Polar"}))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-160-f5788664d60b> in <module>()
#       3 collection = db.movie
#       4 collection.drop
# ----> 5 collection.insert_many(df.to_dict('records'))
#       6 collection.count_documents({})
#       7 #pprint(collection.find_one({"Name": "Polar"}))
#
# /anaconda2/lib/python2.7/site-packages/pymongo/collection.pyc in insert_many(self, documents, ordered, bypass_document_validation, session)
#     751         blk = _Bulk(self, ordered, bypass_document_validation)
#     752         blk.ops = [doc for doc in gen()]
# --> 753         blk.execute(write_concern, session=session)
#     754         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     755
#
# /anaconda2/lib/python2.7/site-packages/pymongo/bulk.pyc in execute(self, write_concern, session)
#     519                 self.execute_no_results(sock_info, generator)
#     520         else:
# --> 521             return self.execute_command(generator, write_concern, session)
#     522
#     523
#
# /anaconda2/lib/python2.7/site-packages/pymongo/bulk.pyc in execute_command(self, generator, write_concern, session)
#     342
#     343         client = self.collection.database.client
# --> 344         with client._tmp_session(session) as s:
#     345             client._retry_with_session(
#     346                 self.is_retryable, retryable_bulk, s, self)
#
# /anaconda2/lib/python2.7/contextlib.pyc in __enter__(self)
#      15     def __enter__(self):
#      16         try:
# ---> 17             return self.gen.next()
#      18         except StopIteration:
#      19             raise RuntimeError("generator didn't yield")
#
# /anaconda2/lib/python2.7/site-packages/pymongo/mongo_client.pyc in _tmp_session(self, session, close)
#    1574             return
#    1575
# -> 1576         s = self._ensure_session(session)
#    1577         if s and close:
#    1578             with s:
#
# /anaconda2/lib/python2.7/site-packages/pymongo/mongo_client.pyc in _ensure_session(self, session)
#    1561             # Don't make implicit sessions causally consistent. Applications
#    1562             # should always opt-in.
# -> 1563             return self.__start_session(True, causal_consistency=False)
#    1564         except (ConfigurationError, InvalidOperation):
#    1565             # Sessions not supported, or multiple users authenticated.
#
# /anaconda2/lib/python2.7/site-packages/pymongo/mongo_client.pyc in __start_session(self, implicit, **kwargs)
#    1514
#    1515         # Raises ConfigurationError if sessions are not supported.
# -> 1516         server_session = self._get_server_session()
#    1517         opts = client_session.SessionOptions(**kwargs)
#    1518         return client_session.ClientSession(
#
# /anaconda2/lib/python2.7/site-packages/pymongo/mongo_client.pyc in _get_server_session(self)
#    1547     def _get_server_session(self):
#    1548         """Internal: start or resume a _ServerSession."""
# -> 1549         return self._topology.get_server_session()
#    1550
#    1551     def _return_server_session(self, server_session, lock):
#
# /anaconda2/lib/python2.7/site-packages/pymongo/topology.pyc in get_server_session(self)
#     425                             any_server_selector,
#     426                             self._settings.server_selection_timeout,
# --> 427                             None)
#     428                 elif not self._description.readable_servers:
#     429                     self._select_servers_loop(
#
# /anaconda2/lib/python2.7/site-packages/pymongo/topology.pyc in _select_servers_loop(self, selector, timeout, address)
#     206             # came after our most recent apply_selector call, since we've
#     207             # held the lock until now.
# --> 208             self._condition.wait(common.MIN_HEARTBEAT_INTERVAL)
#     209             self._description.check_compatible()
#     210             now = _time()
#
# /anaconda2/lib/python2.7/threading.pyc in wait(self, timeout)
#     357                         break
#     358                     delay = min(delay * 2, remaining, .05)
# --> 359                     _sleep(delay)
#     360                 if not gotit:
#     361                     if __debug__:
#
# KeyboardInterrupt:

# %%
cols = ['UserID','MovieID','Rated']
df2 = pd.DataFrame(columns = cols)

# %%
import numpy as np
from random import randint
for i in range(1,1000):
    userid = i
    for k in range(0,52):
        df2 = df2.append({'UserID': userid, 'MovieID': randint(0,301), 'Rated': randint(0,5)}, ignore_index=True)
        k=k+1
    i = i+1

# %%
df2.shape
# Out:
# (51948, 3)

# %%
maxes = df2.groupby(['UserID', 'MovieID']).Rated.transform(max)
df2 = df2.loc[df2.Rated == maxes]
df2.to_csv('User_rating.csv',index=False)

# %%
df2.shape
# Out:
# (48395, 3)

# %%
movie_data = pd.merge(df, df2, on='MovieID')

# %%
movie_data.to_csv("moviedata.csv")
